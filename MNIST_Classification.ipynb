# %% [markdown]
# <a href="https://colab.research.google.com/github/kumaradityaka/Machine-learning/blob/master/MNIST_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'DESCR', 'details', 'categories', 'url'])

# %%
X,y = mnist["data"], mnist['target']
print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
s_d = X[0]
s_d_img = s_d.reshape(28,28)
plt.imshow(s_d_img, cmap = mpl.cm.binary ,interpolation='nearest')
plt.axis("off")
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
y[0]
# Out:
# '5'

# %%
from sklearn.model_selection import train_test_split

# %%
y = y.astype(np.uint8) 
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8, test_size = 0.2)


#y_train_5 = (y_train == 5)
#y_test_5 = (y_test == 5)

# %%
from sklearn.ensemble import RandomForestClassifier
Ran = RandomForestClassifier()
Ran.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
prediction = Ran.predict(X_test)
Ran.score(X_test,y_test)
# Out:
# 0.9686428571428571

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,prediction)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,7))
sns.heatmap(cm,annot = True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(69.0, 0.5, 'Actual')

# %%
clf = KNeighborsClassifier()

# %%
sgd = SGDClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
es = np.array(range(1000))
depth = np.array(range(50))
grc = GridSearchCV(estimator= RandomForestClassifier(),
                    param_grid = { 'n_estimators': es, 'max_depth': depth}, cv = 5)
grc_result = grc.fit(X_train, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# ...

# %%
import tensorflow
